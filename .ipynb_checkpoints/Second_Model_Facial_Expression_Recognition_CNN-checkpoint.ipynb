# %%
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# 2023-01-12 16:26:19.584561: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
import tensorflow_addons as tfa

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
# image cropped, rescaled to 48x48 already

FER_PATH="CK_PLUS/CK+48" 
FER_PATH= pathlib.Path(FER_PATH)
image_count = len(list(FER_PATH.glob('*/*.png')))
#print(image_count)

# %%
anger = list(CK_PATH.glob('anger/*'))
contempt = list(CK_PATH.glob('contempt/*'))
disgust = list(CK_PATH.glob('disgust/*'))
fear = list(CK_PATH.glob('fear/*'))
happy = list(CK_PATH.glob('happy/*'))
sadness = list(CK_PATH.glob('sadness/*'))
surprise = list(CK_PATH.glob('surprise/*'))
#PIL.Image.open(str(happy[0]))
#print image

# %%
batch_size=32 #test
img_height = 48
img_width = 48

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
CK_PATH,
labels='inferred',
label_mode='int',
validation_split=0.15,
subset="training",
seed=100,
image_size=(img_height, img_width),
batch_size=batch_size)

test_ds = tf.keras.utils.image_dataset_from_directory(
CK_PATH,
labels='inferred',
label_mode='int',
validation_split=0.15,
subset="validation",
seed=100,
image_size=(img_height, img_width),
batch_size=batch_size)
# Out:
# Found 981 files belonging to 7 classes.
# Using 834 files for training.
# Found 981 files belonging to 7 classes.
# Using 147 files for validation.
# 2023-01-12 16:26:35.154583: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
class_names = train_ds.class_names
class_no = len(class_names)
#print(class_names )

# %%
"""
plt.figure(figsize=(10, 10)) #first 9 image with class
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
        
"""

# %%
for image_batch, labels_batch in train_ds:
    input_shape = image_batch.shape
    label_shape = labels_batch.shape
    print(input_shape)
    #print(label_shape )
    break
# Out:
# (32, 48, 48, 3)

# %%
image_batch = image_batch.reshape(batch_size, img_height, img_width, 3)
image_batch = image_batch.astype('float32')

# %%
def rotation(image,angle):
    rot_image = tfa.image.rotate(image, angle, interpolation = 'nearest')

    return rot_image
    

#5 degrees of rotation at a step of 0.1 degrees
def rotation_list(image):

    angles_rad = []
    image_list=[]
    for i in range(1,51):
        angles_rad +=[0.1*i* np.pi / 180] 

        image_list +=[ rotation(image,angles_rad[i-1])]
    return image_list

# %%
#plt.imshow(rotation_list(image_batch[0])[20])

# %%
aut_train_ds = train_ds.map(lambda x, y: (rotation_list(x), y))
aut_test_ds = test_ds.map(lambda x, y: (rotation_list(x), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE) #no rotation
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)


aut_train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
aut_test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#FIRST PROPOSED MODEL
#-------------------
model = keras.Sequential()
model.add(layers.experimental.preprocessing.Rescaling(1.0 / 255)) #normalization

#--convolutional layer x3---
model.add(tf.keras.layers.Conv2D(6, kernel_size=(3, 3),padding='same',  activation='relu', input_shape=(image_batch.shape[1], image_batch.shape[2], 3) ))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=(image_batch.shape[1], image_batch.shape[2], 3) ))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(image_batch.shape[1], image_batch.shape[2], 3) ))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

#--Fully Connected Layers x2---

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256,activation=None))
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(128,activation=None))
model.add(tf.keras.layers.Dropout(0.5))

#--

model.add(tf.keras.layers.Dense(class_no, activation='softmax'))


#-------------------

# %%
model.build(input_shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (32, 48, 48, 3)           0
#
#  conv2d (Conv2D)             (32, 48, 48, 6)           168
#
#  batch_normalization (BatchN  (32, 48, 48, 6)          24
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (32, 24, 24, 6)          0
#  )
#
#  conv2d_1 (Conv2D)           (32, 22, 22, 16)          880
#
#  batch_normalization_1 (Batc  (32, 22, 22, 16)         64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (32, 11, 11, 16)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 9, 9, 128)           18560
#
#  batch_normalization_2 (Batc  (32, 9, 9, 128)          512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (32, 4, 4, 128)          0
#  2D)
#
#  flatten (Flatten)           (32, 2048)                0
#
#  dense (Dense)               (32, 256)                 524544
#
#  dropout (Dropout)           (32, 256)                 0
#
#  dense_1 (Dense)             (32, 128)                 32896
#
#  dropout_1 (Dropout)         (32, 128)                 0
#
#  dense_2 (Dense)             (32, 7)                   903
#
# =================================================================
# Total params: 578,551
# Trainable params: 578,251
# Non-trainable params: 300
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
#history= model.fit(train_ds, batch_size=7, epochs=100,verbose=1,validation_data = test_ds)

history= model.fit(aut_train_ds, batch_size=7, epochs=100,verbose=1,validation_data = aut_test_ds)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 2s 40ms/step - loss: 7.1668 - accuracy: 0.3933 - val_loss: 1.9171 - val_accuracy: 0.2245
# Epoch 2/100
# 27/27 [==============================] - 1s 29ms/step - loss: 3.6824 - accuracy: 0.6439 - val_loss: 2.8867 - val_accuracy: 0.0612
# Epoch 3/100
# 27/27 [==============================] - 1s 29ms/step - loss: 2.1735 - accuracy: 0.7422 - val_loss: 3.7771 - val_accuracy: 0.0612
# Epoch 4/100
# 27/27 [==============================] - 1s 29ms/step - loss: 1.0816 - accuracy: 0.8429 - val_loss: 5.4055 - val_accuracy: 0.0612
# Epoch 5/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.6789 - accuracy: 0.8897 - val_loss: 6.0754 - val_accuracy: 0.0612
# Epoch 6/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.4408 - accuracy: 0.9149 - val_loss: 5.3400 - val_accuracy: 0.0612
# Epoch 7/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3245 - accuracy: 0.9305 - val_loss: 5.2485 - val_accuracy: 0.0680
# Epoch 8/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3628 - accuracy: 0.9388 - val_loss: 6.8863 - val_accuracy: 0.0680
# Epoch 9/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3092 - accuracy: 0.9472 - val_loss: 4.9876 - val_accuracy: 0.1429
# Epoch 10/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2713 - accuracy: 0.9412 - val_loss: 4.4334 - val_accuracy: 0.2109
# Epoch 11/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1414 - accuracy: 0.9700 - val_loss: 3.2751 - val_accuracy: 0.4286
# Epoch 12/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1233 - accuracy: 0.9712 - val_loss: 2.7702 - val_accuracy: 0.4898
# Epoch 13/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1656 - accuracy: 0.9640 - val_loss: 3.3636 - val_accuracy: 0.4558
# Epoch 14/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0746 - accuracy: 0.9820 - val_loss: 1.7477 - val_accuracy: 0.7007
# Epoch 15/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1054 - accuracy: 0.9820 - val_loss: 2.1938 - val_accuracy: 0.6599
# Epoch 16/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1410 - accuracy: 0.9700 - val_loss: 1.0546 - val_accuracy: 0.8299
# Epoch 17/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1679 - accuracy: 0.9724 - val_loss: 0.4369 - val_accuracy: 0.8980
# Epoch 18/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0625 - accuracy: 0.9880 - val_loss: 0.6030 - val_accuracy: 0.8707
# Epoch 19/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0955 - accuracy: 0.9796 - val_loss: 0.4930 - val_accuracy: 0.9048
# Epoch 20/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1347 - accuracy: 0.9736 - val_loss: 0.4872 - val_accuracy: 0.9116
# Epoch 21/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7824 - accuracy: 0.9245 - val_loss: 0.4604 - val_accuracy: 0.9116
# Epoch 22/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3433 - accuracy: 0.9484 - val_loss: 0.3517 - val_accuracy: 0.9660
# Epoch 23/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2195 - accuracy: 0.9676 - val_loss: 0.0876 - val_accuracy: 0.9728
# Epoch 24/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1212 - accuracy: 0.9820 - val_loss: 0.0147 - val_accuracy: 0.9932
# Epoch 25/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0926 - accuracy: 0.9868 - val_loss: 0.0989 - val_accuracy: 0.9796
# Epoch 26/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1292 - accuracy: 0.9796 - val_loss: 0.0071 - val_accuracy: 0.9932
# Epoch 27/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0724 - accuracy: 0.9904 - val_loss: 0.1578 - val_accuracy: 0.9728
# Epoch 28/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0440 - accuracy: 0.9940 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0235 - accuracy: 0.9928 - val_loss: 1.3540e-04 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0254 - accuracy: 0.9928 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0380 - accuracy: 0.9928 - val_loss: 5.2750e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0631 - accuracy: 0.9916 - val_loss: 0.0215 - val_accuracy: 0.9932
# Epoch 33/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0933 - accuracy: 0.9880 - val_loss: 0.2516 - val_accuracy: 0.9592
# Epoch 34/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1859 - accuracy: 0.9796 - val_loss: 0.0065 - val_accuracy: 0.9932
# Epoch 35/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0716 - accuracy: 0.9892 - val_loss: 0.0291 - val_accuracy: 0.9932
# Epoch 36/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1207 - accuracy: 0.9832 - val_loss: 3.2681e-05 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1719 - accuracy: 0.9844 - val_loss: 0.6701 - val_accuracy: 0.9456
# Epoch 38/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1955 - accuracy: 0.9760 - val_loss: 0.0381 - val_accuracy: 0.9864
# Epoch 39/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1081 - accuracy: 0.9868 - val_loss: 0.0509 - val_accuracy: 0.9932
# Epoch 40/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1073 - accuracy: 0.9892 - val_loss: 0.2351 - val_accuracy: 0.9728
# Epoch 41/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1330 - accuracy: 0.9880 - val_loss: 0.2310 - val_accuracy: 0.9592
# Epoch 42/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0647 - accuracy: 0.9856 - val_loss: 1.8005 - val_accuracy: 0.8503
# Epoch 43/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1598 - accuracy: 0.9820 - val_loss: 0.1322 - val_accuracy: 0.9796
# Epoch 44/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2070 - accuracy: 0.9772 - val_loss: 0.1196 - val_accuracy: 0.9728
# Epoch 45/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0359 - accuracy: 0.9940 - val_loss: 0.1222 - val_accuracy: 0.9796
# Epoch 46/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0654 - accuracy: 0.9856 - val_loss: 0.1477 - val_accuracy: 0.9932
# Epoch 47/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1435 - accuracy: 0.9820 - val_loss: 0.6326 - val_accuracy: 0.9116
# Epoch 48/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2399 - accuracy: 0.9772 - val_loss: 0.1967 - val_accuracy: 0.9728
# Epoch 49/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1758 - accuracy: 0.9820 - val_loss: 0.4719 - val_accuracy: 0.9796
# Epoch 50/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2650 - accuracy: 0.9772 - val_loss: 0.6493 - val_accuracy: 0.9592
# Epoch 51/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2440 - accuracy: 0.9796 - val_loss: 0.7791 - val_accuracy: 0.9456
# Epoch 52/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1368 - accuracy: 0.9868 - val_loss: 0.3129 - val_accuracy: 0.9592
# Epoch 53/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1702 - accuracy: 0.9856 - val_loss: 0.0320 - val_accuracy: 0.9864
# Epoch 54/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0321 - accuracy: 0.9964 - val_loss: 0.0866 - val_accuracy: 0.9864
# Epoch 55/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0242 - accuracy: 0.9952 - val_loss: 0.0310 - val_accuracy: 0.9864
# Epoch 56/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0502 - accuracy: 0.9964 - val_loss: 0.4123 - val_accuracy: 0.9728
# Epoch 57/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0569 - accuracy: 0.9928 - val_loss: 0.2437 - val_accuracy: 0.9592
# Epoch 58/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0907 - accuracy: 0.9904 - val_loss: 0.1726 - val_accuracy: 0.9660
# Epoch 59/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0323 - accuracy: 0.9952 - val_loss: 0.4618 - val_accuracy: 0.9592
# Epoch 60/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0664 - accuracy: 0.9916 - val_loss: 0.1702 - val_accuracy: 0.9796
# Epoch 61/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0396 - accuracy: 0.9916 - val_loss: 0.5452 - val_accuracy: 0.9524
# Epoch 62/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0989 - accuracy: 0.9832 - val_loss: 0.2826 - val_accuracy: 0.9660
# Epoch 63/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0976 - accuracy: 0.9892 - val_loss: 0.3119 - val_accuracy: 0.9728
# Epoch 64/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1521 - accuracy: 0.9916 - val_loss: 0.4994 - val_accuracy: 0.9728
# Epoch 65/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1095 - accuracy: 0.9892 - val_loss: 0.2516 - val_accuracy: 0.9796
# Epoch 66/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1002 - accuracy: 0.9868 - val_loss: 0.0731 - val_accuracy: 0.9864
# Epoch 67/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1095 - accuracy: 0.9904 - val_loss: 0.8060 - val_accuracy: 0.9660
# Epoch 68/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1291 - accuracy: 0.9892 - val_loss: 0.2438 - val_accuracy: 0.9660
# Epoch 69/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0938 - accuracy: 0.9928 - val_loss: 9.8650 - val_accuracy: 0.6395
# Epoch 70/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0858 - accuracy: 0.9904 - val_loss: 0.6370 - val_accuracy: 0.9728
# Epoch 71/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0930 - accuracy: 0.9916 - val_loss: 0.0290 - val_accuracy: 0.9932
# Epoch 72/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0828 - accuracy: 0.9928 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 73/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0158 - accuracy: 0.9964 - val_loss: 0.0620 - val_accuracy: 0.9864
# Epoch 74/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0282 - accuracy: 0.9952 - val_loss: 0.0388 - val_accuracy: 0.9932
# Epoch 75/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0575 - accuracy: 0.9904 - val_loss: 1.2723e-06 - val_accuracy: 1.0000
# Epoch 76/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0956 - accuracy: 0.9892 - val_loss: 0.0108 - val_accuracy: 0.9932
# Epoch 77/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0671 - accuracy: 0.9940 - val_loss: 0.5277 - val_accuracy: 0.9660
# Epoch 78/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0364 - accuracy: 0.9928 - val_loss: 2.6214e-06 - val_accuracy: 1.0000
# Epoch 79/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0957 - accuracy: 0.9916 - val_loss: 0.2294 - val_accuracy: 0.9660
# Epoch 80/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0497 - accuracy: 0.9976 - val_loss: 6.2962e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0867 - accuracy: 0.9904 - val_loss: 0.0992 - val_accuracy: 0.9864
# Epoch 82/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.8058 - val_accuracy: 0.9388
# Epoch 83/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1496 - accuracy: 0.9880 - val_loss: 0.0552 - val_accuracy: 0.9932
# Epoch 84/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2453 - accuracy: 0.9880 - val_loss: 1.5987 - val_accuracy: 0.9388
# Epoch 85/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1011 - accuracy: 0.9880 - val_loss: 0.5964 - val_accuracy: 0.9660
# Epoch 86/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0469 - accuracy: 0.9940 - val_loss: 0.1962 - val_accuracy: 0.9864
# Epoch 87/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0918 - accuracy: 0.9940 - val_loss: 0.0811 - val_accuracy: 0.9932
# Epoch 88/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0409 - accuracy: 0.9964 - val_loss: 0.1765 - val_accuracy: 0.9796
# Epoch 89/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0656 - accuracy: 0.9952 - val_loss: 0.4758 - val_accuracy: 0.9728
# Epoch 90/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0346 - accuracy: 0.9964 - val_loss: 0.0308 - val_accuracy: 0.9932
# Epoch 91/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0564 - accuracy: 0.9952 - val_loss: 0.9248 - val_accuracy: 0.9388
# Epoch 92/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1766 - accuracy: 0.9928 - val_loss: 0.4085 - val_accuracy: 0.9796
# Epoch 93/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0815 - accuracy: 0.9928 - val_loss: 0.0788 - val_accuracy: 0.9864
# Epoch 94/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0792 - accuracy: 0.9916 - val_loss: 0.5159 - val_accuracy: 0.9524
# Epoch 95/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0605 - accuracy: 0.9976 - val_loss: 0.2964 - val_accuracy: 0.9728
# Epoch 96/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0191 - accuracy: 0.9976 - val_loss: 0.3052 - val_accuracy: 0.9660
# Epoch 97/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0887 - val_accuracy: 0.9864
# Epoch 98/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1226 - accuracy: 0.9940 - val_loss: 0.4133 - val_accuracy: 0.9864
# Epoch 99/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1813 - accuracy: 0.9868 - val_loss: 2.2560 - val_accuracy: 0.8844
# Epoch 100/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1767 - accuracy: 0.9904 - val_loss: 1.3955 - val_accuracy: 0.9456

# %%
history_dict = history.history
#print(history_dict.keys())

# %%
plt.plot(history_dict['accuracy'], label='train accuracy')
#plt.plot(history_dict['loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(history_dict['loss'], label='val loss')
plt.legend()
plt.show()
